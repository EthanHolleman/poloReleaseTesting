# %% [markdown]
# # Test reading cocktail data with pandas

# %% [markdown]
# Previously used Python csv package (gross) thinking about updating to pandas. Frankly, if I had been a better pandas user earlier on I should have been using it a lot more in this program

# %%
import pandas as pd

# %%
new_cocktail = pd.read_csv('../src/data/cocktail_data/21_C1536.csv', skiprows=1)
new_cocktail
# Out:
#       Well position in plate Cocktail #       96 Deep\nWell #  \
# 0                          1   21_C0001        HR Slice pH A1
# 1                          5   21_C0002        HR Slice pH A2
# 2                          9   21_C0003        HR Slice pH A3
# 3                         13   21_C0004        HR Slice pH A4
# 4                         17   21_C0005        HR Slice pH A5
# ...                      ...        ...                   ...
# 1531                    1520   21_C1532   HR SaltRx Screen H8
# 1532                    1524   21_C1533   HR SaltRx Screen H9
# 1533                    1528   21_C1534  HR SaltRx Screen H10
# 1534                    1532   21_C1535  HR SaltRx Screen H11
# 1535                    1536   21_C1536  HR SaltRx Screen H12
#
#      Chemical Additive Chemical Formula                       Conc  \
# 0                  NaN              NaN                        NaN
# 1                  NaN              NaN                        NaN
# ...

# %%
additive_concentration_index_pairs = [
    (3, 5),
    (6, 7),
    (9, 10),
    (11, 12),
    (13, 14)
]

# %%
set(new_cocktail['Unnamed: 15'])
# Out:
# {'0.005M', nan}

# %% [markdown]
# Hmm so this column is not empty and seems to be for concentrations. What about the previous column then

# %%
set(new_cocktail['Unnamed: 14'])
# Out:
# {'Magnesium chloride hexahydrate', nan}

# %%
s = '1,21_C0001,HR Slice pH A1,,,,Citric acid,0.5 M,3.5,PEG 3350,15% (w/v),,,,,'.split(',')
len(s)
# Out:
# 16
